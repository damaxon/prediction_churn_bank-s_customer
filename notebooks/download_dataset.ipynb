# %%
import opendatasets as od 


od.download_kaggle_dataset("https://www.kaggle.com/datasets/radheshyamkollipara/bank-customer-churn","C:/Users/User/Documents/VSC/prediction_churn_bank-s_customer/data")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Dataset URL: https://www.kaggle.com/datasets/radheshyamkollipara/bank-customer-churn
# ...
# 100%|██████████| 307k/307k [00:00<00:00, 750kB/s]
